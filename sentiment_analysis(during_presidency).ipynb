# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Path to your CSV file on Google Drive
csv_file_path = '/content/drive/MyDrive/DonaldTrump (p) 2017-2020 - Sheet1 - DonaldTrump (p) 2017-2020 - Sheet1 (1).csv'

# Read the CSV file using pandas
data = pd.read_csv(csv_file_path)

# Display the first few rows of the DataFrame
data.head()
# Out:
#              id                                               text  \
# 0  9.480000e+17  HAPPY NEW YEAR! We are MAKING AMERICA GREAT AG...
# 1  9.480000e+17  As our Country rapidly grows stronger and smar...
# 2  9.480000e+17  Iran, the Number One State of Sponsored Terror...
# 3  9.480000e+17  What a year it’s been, and we're just getting ...
# 4  9.480000e+17  My deepest condolences to the victims of the t...
#
#                  device  retweets     fa              date
# 0    Twitter for iPhone    166739  32589  12/31/2017 23:43
# 1    Twitter for iPhone    169966  36017  12/31/2017 22:18
# 2    Twitter for iPhone     93121  25822  12/31/2017 22:00
# 3  Twitter Media Studio    117478  26486  12/31/2017 19:06
# 4    Twitter for iPhone     75389  14746  12/31/2017 18:36

# %%
data.columns
# Out:
# Index(['id', 'text', 'device', 'retweets', 'fa', 'date'], dtype='object')

# %%
# List of columns to drop
columns_to_drop = ['id', 'fa', 'date', 'device']

# Drop the specified columns
df = data.drop(columns=columns_to_drop)

# %%
df.columns
# Out:
# Index(['text', 'retweets'], dtype='object')

# %%
df.head()
# Out:
#                                                 text  retweets
# 0  HAPPY NEW YEAR! We are MAKING AMERICA GREAT AG...    166739
# 1  As our Country rapidly grows stronger and smar...    169966
# 2  Iran, the Number One State of Sponsored Terror...     93121
# 3  What a year it’s been, and we're just getting ...    117478
# 4  My deepest condolences to the victims of the t...     75389

# %%
df.value_counts("retweets")
# Out:
# retweets
# 0          9849
# 1            21
# 2            11
# 4             6
# 5             5
#            ...
# 62350         1
# 62351         1
# 62373         1
# 62376         1
# 1869706       1
# Length: 15636, dtype: int64

# %%
df.loc[df.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [text, retweets]
# Index: []

# %%
# !pip install advertools

# %%
# %config InlineBackend.figure_format = 'retina' # high resolution plotting
import matplotlib.pyplot as plt
import pandas as pd
import advertools as adv
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', 280)
adv.__version__
# Out:
# '0.13.5'

# %% [markdown]
# # **MENTION**

# %%
mention_summary = adv.extract_mentions(df['text'])
mention_summary.keys()
# Out:
# dict_keys(['mentions', 'mentions_flat', 'mention_counts', 'mention_freq', 'top_mentions', 'overview'])

# %%
mention_summary['top_mentions'][:100]
# Out:
# [('@realdonaldtrump', 2659),
#  ('@whitehouse', 840),
#  ('@foxnews', 534),
#  ('@foxandfriends', 362),
#  ('@teamtrump', 287),
#  ('@gopchairwoman', 219),
#  ('@potus', 196),
#  ('@seanhannity', 183),
#  ('@jim_jordan', 177),
#  ('@flotus', 159),
#  ('@danscavino', 149),
#  ('@gop', 145),
#  ('@cnn', 144),
#  ('@greggjarrett', 142),
#  ('@dbongino', 142),
#  ('@breitbartnews', 136),
#  ('@loudobbs', 135),
#  ('@ivankatrump', 129),
#  ('@donaldjtrumpjr', 127),
#  ('@tomfitton', 127),
#  ('@nytimes', 123),
#  ('@oann', 122),
#  ('@marklevinshow', 122),
#  ('@lindseygrahamsc', 118),
#  ('@scavino45', 115),
#  ('@senatemajldr', 108),
#  ('@vp', 107),
#  ('@repmarkmeadows', 100),
#  ('@mariabartiromo', 99),
#  ('@paulsperry_', 93),
#  ('@judicialwatch', 90),
#  ('@gopleader', 89),
#  ('@mike_pence', 86),
#  ('@erictrump', 82),
#  ('@senategop', 79),
#  ('@charliekirk11', 77),
#  ('@trumpwarroom', 76),
#  ('@ingrahamangle', 74),
#  ('@kimstrassel', 64),
#  ('@mzhemingway', 64),
# ...

# %%
df['user_id']=mention_summary['mentions']

# %%
df.shape
# Out:
# (26517, 3)

# %%
df.head()
# Out:
#                                                                                                                                                                                                                                   text  \
# 0                                                                                                                                     HAPPY NEW YEAR! We are MAKING AMERICA GREAT AGAIN, and much faster than anyone thought possible!
# 1  As our Country rapidly grows stronger and smarter, I want to wish all of my friends, supporters, enemies, haters, and even the very dishonest Fake News Media, a Happy and Healthy New Year. 2018 will be a great year for America!
# 2                  Iran, the Number One State of Sponsored Terror with numerous violations of Human Rights occurring on an hourly basis, has now closed down the Internet so that peaceful demonstrators cannot communicate. Not good!
# ...

# %% [markdown]
# ## Sentiment Analysis

# %%
df1=pd.read_csv('/content/drive/MyDrive/@mentions_list(trump_P).csv')

# %%
df1.head()
# Out:
#             user_id  frequency
# 0  @realdonaldtrump       2659
# 1       @whitehouse        840
# 2          @foxnews        534
# 3    @foxandfriends        362
# 4        @teamtrump        287

# %%
df1.shape
# Out:
# (3156, 2)

# %%
pip install vaderSentiment

# %%
#sentiment analysis
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
from statistics import mode

# Create a SentimentIntensityAnalyzer object
analyzer = SentimentIntensityAnalyzer()

# Function to get sentiment label
def get_sentiment_label(score):
    if score >= 0.05:
        return "Positive"
    elif score <= -0.05:
        return "Negative"
    else:
        return "Neutral"


# Perform sentiment analysis and add sentiment column
df['Sentiment_Scores'] = df['text'].apply(lambda text: analyzer.polarity_scores(text))
df['Sentiment'] = df['Sentiment_Scores'].apply(lambda scores: get_sentiment_label(scores['compound']))



for index, row in df1.iterrows():
    userid = row['user_id']

    # Filter df3 to get tweets containing the userid
    matching_tweets = df[df['text'].str.contains(userid, case=False)]

    if not matching_tweets.empty:
        # Calculate sentiment scores for matching tweets
        matching_tweets['sentiment_score'] = matching_tweets['text'].apply(lambda x: analyzer.polarity_scores(x)['compound'])

        # Get sentiment labels using the provided function
        matching_tweets['sentiment_label'] = matching_tweets['sentiment_score'].apply(get_sentiment_label)

        # Calculate the mode sentiment
        mode_sentiment = mode(matching_tweets['sentiment_label'])

        # Add mode sentiment to df2
        df1.at[index, 'sentiment'] = mode_sentiment

# Save the updated df2 with sentiment information
df1.to_csv('Trump_sentiment_analysis(during_presidency).csv', index=False)
# Out:
# Streaming output truncated to the last 5000 lines.
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matching_tweets['sentiment_score'] = matching_tweets['text'].apply(lambda x: analyzer.polarity_scores(x)['compound'])
# <ipython-input-22-95b8fb4b4986>:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matching_tweets['sentiment_label'] = matching_tweets['sentiment_score'].apply(get_sentiment_label)
# <ipython-input-22-95b8fb4b4986>:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df.head()
# Out:
#                                                                                                                                                                                                                                   text  \
# 0                                                                                                                                     HAPPY NEW YEAR! We are MAKING AMERICA GREAT AGAIN, and much faster than anyone thought possible!
# 1  As our Country rapidly grows stronger and smarter, I want to wish all of my friends, supporters, enemies, haters, and even the very dishonest Fake News Media, a Happy and Healthy New Year. 2018 will be a great year for America!
# 2                  Iran, the Number One State of Sponsored Terror with numerous violations of Human Rights occurring on an hourly basis, has now closed down the Internet so that peaceful demonstrators cannot communicate. Not good!
# ...

# %%
df2=pd.read_csv("/content/Trump_sentiment_analysis(during_presidency).csv")
df2.head()
# Out:
#             user_id  frequency sentiment
# 0  @realdonaldtrump       2659  Positive
# 1       @whitehouse        840  Positive
# 2          @foxnews        534  Positive
# 3    @foxandfriends        362  Positive
# 4        @teamtrump        287  Positive

# %%
df2.shape
# Out:
# (3156, 3)

# %%
# Rename the column
df2.rename(columns={'frequency': 'Trump_freq','sentiment':'Trump_sentiment'},inplace=True)

# %%
df2.head()
# Out:
#             user_id  Trump_freq Trump_sentiment
# 0  @realdonaldtrump        2659        Positive
# 1       @whitehouse         840        Positive
# 2          @foxnews         534        Positive
# 3    @foxandfriends         362        Positive
# 4        @teamtrump         287        Positive

# %%
df3=pd.read_csv("/content/drive/MyDrive/Obama_sentiment_analysis(P).csv")
df3.head()
# Out:
#           user_id  frequency sentiment_during_presidency
# 0  @michelleobama         29                    Positive
# 1            @ofa         28                    Positive
# 2     @whitehouse         24                    Positive
# 3      @obama2012         13                     Neutral
# 4             @vp         12                    Positive

# %%
# Rename the column
df3.rename(columns={'frequency': 'Obama_freq','sentiment':'Obama_sentiment'},inplace=True)

# %%
df3.head()
# Out:
#           user_id  Obama_freq sentiment_during_presidency
# 0  @michelleobama          29                    Positive
# 1            @ofa          28                    Positive
# 2     @whitehouse          24                    Positive
# 3      @obama2012          13                     Neutral
# 4             @vp          12                    Positive

# %%
sentiment_of_presidents = pd.merge(df2, df3, on='user_id', how='inner')

# %%
sentiment_of_presidents.head()
# Out:
#        user_id  Trump_freq Trump_sentiment  Obama_freq  \
# 0  @whitehouse         840        Positive          24
# 1       @potus         196        Positive           1
# 2      @flotus         159        Positive           6
# 3         @cnn         144        Negative           1
# 4     @nytimes         123        Negative           6
#
#   sentiment_during_presidency
# 0                    Positive
# 1                    Positive
# 2                    Positive
# 3                    Positive
# 4                     Neutral

# %%
sentiment_of_presidents.shape
# Out:
# (57, 5)

# %%
csv_file_path = 'sentiment_of_presidents.csv'
sentiment_of_presidents.to_csv(csv_file_path, index=False)
